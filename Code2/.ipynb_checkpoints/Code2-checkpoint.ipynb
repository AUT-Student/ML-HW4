# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Dataset Overview

# %%
fig, ax = plt.subplots(2,2)

for dataset_i, dataset_name in enumerate(["Compound", "D31", "pathbased", "spiral"]):
    path = "./data/"+dataset_name+".txt"
    dataset = pd.read_csv(path, sep="\t", names=["X", "Y", "Class"])

    for class_id in set(dataset["Class"]):
        ax[int(dataset_i/2)][dataset_i%2].scatter(
            dataset[dataset["Class"]==class_id]["X"],
            dataset[dataset["Class"]==class_id]["Y"]
        )
    ax[int(dataset_i/2)][dataset_i%2].title.set_text(dataset_name)

fig.set_size_inches(11, 11)
plt.show()

# %%
dataset = pd.read_csv("./data/rings.txt", sep="\t", names=["Class", "X", "Y", "Z"])

fig = plt.figure(figsize=(11, 11))
ax = fig.add_subplot(projection='3d')

for class_id in set(dataset["Class"]):
    ax.scatter(dataset[dataset["Class"]==class_id]["X"],
               dataset[dataset["Class"]==class_id]["Y"],
               dataset[dataset["Class"]==class_id]["Z"]
    )
    
ax.title.set_text("rings")

plt.show()

# %% [markdown]
# # DBSCAN

# %%
def find_neighbours(dataset, data, e):
    remain_columns = list(set(dataset.columns) - set(["Class", "Status", "Cluster"]))
    
    for i, data2 in dataset.iterrows():
        dataset.at[i, "Distance"] = np.linalg.norm(data[remain_columns] - data2[remain_columns])
        
    dataset_output = dataset[dataset["Distance"]<e]
    dataset_output = dataset_output.drop([data.name])
    dataset_output = dataset_output.drop(columns = ["Distance"])
    
    del dataset["Distance"]
    
    return dataset_output

# %%
from queue import Queue

def dbscan(dataset, e, min_pts):
    del dataset["Class"]
    dataset["Status"] = "Unknown"
    dataset["Cluster"] = -1
    
    number_cluster = 0
    for i, data in dataset.iterrows():
        print(f"i = {i}")
        print(dataset)
        if data["Status"] == "Unknown":
            neighbours = find_neighbours(dataset, data, e)
            
            if len(neighbours) < min_pts:
                dataset.at[i, "Status"] = "Outlier"
            else:
                dataset.at[i, "Status"] = "Core"
                dataset.at[i, "Cluster"] = number_cluster
                                
                q = Queue()
                
                for j, data_n in neighbours.iterrows():
                    q.put((j, data_n))
                    
                while(not q.empty()):
                    j, data_n = q.get()
                          
                    if data_n["Status"] == "Outlier":
                        dataset.at[j, "Status"] = "Border"
                        dataset.at[j, "Cluster"] = number_cluster
                    
                    if data_n["Status"] == "Unknown":
                        print(f"In while item = {data_n.name}")
                        
                        if data_n.name == 5:
                            print(f"dataset = \n {dataset}\n")
                        
                        dataset.at[j, "Cluster"] = number_cluster
                        neighbours_n = find_neighbours(dataset, data_n, e)
                        
                        if len(neighbours_n) <min_pts:
                            dataset.at[j, "Status"] = "Border"
                        else:
                            dataset.at[j, "Status"] = "Core"
                            for j, data_n in neighbours_n.iterrows():
                                q.put((j, data_n)) 
                                
                number_cluster += 1

# %%
dataset = pd.read_csv("./data/spiral.txt", sep="\t", names=["Class", "X", "Y"])

# %%
dataset_clustered = dbscan(dataset, e=5, min_pts=5)
# Out:
# i = 0
#          X  Y   Status  Cluster
# 0     7.95  3  Unknown       -1
# 1     7.30  3  Unknown       -1
# 2     6.65  3  Unknown       -1
# 3     6.00  3  Unknown       -1
# 4     5.55  3  Unknown       -1
# ..     ... ..      ...      ...
# 307  13.85  2  Unknown       -1
# 308  14.05  2  Unknown       -1
# 309  14.25  2  Unknown       -1
# 310  14.50  2  Unknown       -1
# 311  14.60  2  Unknown       -1
#
# [312 rows x 4 columns]
# In while item = 1
# In while item = 2
# In while item = 3
# In while item = 4
# In while item = 5
# dataset =
#           X  Y   Status  Cluster
# 0     7.95  3     Core        0
# 1     7.30  3     Core        0
# 2     6.65  3     Core        0
# 3     6.00  3     Core        0
# 4     5.55  3     Core        0
# ..     ... ..      ...      ...
# 307  13.85  2  Unknown       -1
# 308  14.05  2  Unknown       -1
# 309  14.25  2  Unknown       -1
# 310  14.50  2  Unknown       -1
# 311  14.60  2  Unknown       -1
#
# [312 rows x 4 columns]
#
# In while item = 6
# In while item = 7
# In while item = 8
# In while item = 9
# In while item = 10
# In while item = 11
# In while item = 12
# In while item = 13
# In while item = 15
# In while item = 16
# In while item = 17
# In while item = 18
# In while item = 19
# In while item = 20
# In while item = 21
# In while item = 22
# In while item = 23
# In while item = 24
# In while item = 25
# In while item = 26
# In while item = 27
# In while item = 28
# In while item = 29
# In while item = 30
# In while item = 31
# In while item = 32
# In while item = 33
# In while item = 34
# In while item = 35
# In while item = 136
# In while item = 137
# In while item = 138
# In while item = 139
# In while item = 140
# In while item = 141
# In while item = 142
# In while item = 143
# In while item = 144
# In while item = 145
# In while item = 146
# In while item = 147
# In while item = 148
# In while item = 149
# In while item = 150
# In while item = 151
# In while item = 152
# In while item = 153
# In while item = 154
# In while item = 155
# In while item = 156
# In while item = 157
# In while item = 158
# In while item = 159
# In while item = 160
# In while item = 161
# In while item = 162
# In while item = 163
# In while item = 164
# In while item = 165
# In while item = 166
# In while item = 167
# In while item = 168
# In while item = 169
# In while item = 170
# In while item = 171
# In while item = 207
# In while item = 208
# In while item = 209
# In while item = 210
# In while item = 274
# In while item = 275
# In while item = 276
# In while item = 277
# In while item = 278
# In while item = 279
# In while item = 280
# In while item = 281
# In while item = 282
# In while item = 283
# In while item = 284
# In while item = 285
# In while item = 286
# In while item = 287
# In while item = 288
# In while item = 289
# In while item = 290
# In while item = 291
# In while item = 292
# In while item = 293
# In while item = 294
# In while item = 295
# In while item = 296
# In while item = 297
# In while item = 298
# In while item = 299
# In while item = 300
# In while item = 2
# In while item = 3
# In while item = 4
# In while item = 5
# dataset =
#           X  Y   Status  Cluster
# 0     7.95  3     Core        0
# 1     7.30  3     Core        0
# 2     6.65  3     Core        0
# 3     6.00  3     Core        0
# 4     5.55  3     Core        0
# ..     ... ..      ...      ...
# 307  13.85  2  Unknown       -1
# 308  14.05  2  Unknown       -1
# 309  14.25  2  Unknown       -1
# 310  14.50  2  Unknown       -1
# 311  14.60  2  Unknown       -1
#
# [312 rows x 4 columns]
#
# In while item = 6
# In while item = 7
# In while item = 8
# In while item = 9
# In while item = 10
# In while item = 11
# In while item = 12
# In while item = 13
# In while item = 14
# In while item = 15
# In while item = 16
# In while item = 17
# In while item = 18
# In while item = 19
# In while item = 20
# In while item = 21
# In while item = 22
# In while item = 23
# In while item = 24
# In while item = 25
# In while item = 26
# In while item = 27
# In while item = 28
# In while item = 29
# In while item = 30
# In while item = 31
# In while item = 32
# In while item = 33
# In while item = 34
# In while item = 137
# In while item = 138
# In while item = 139
# In while item = 140
# In while item = 141
# In while item = 142
# In while item = 143
# In while item = 144
# In while item = 145
# In while item = 146
# In while item = 147
# In while item = 148
# In while item = 149
# In while item = 150
# In while item = 151
# In while item = 152
# In while item = 153
# In while item = 154
# In while item = 155
# In while item = 156
# In while item = 157
# In while item = 158
# In while item = 159
# In while item = 160
# In while item = 161
# In while item = 162
# In while item = 163
# In while item = 164
# In while item = 165
# In while item = 166
# In while item = 167
# In while item = 168
# In while item = 169
# In while item = 170
# In while item = 207
# In while item = 208
# In while item = 209
# In while item = 277
# In while item = 278
# In while item = 279
# In while item = 280
# In while item = 281
# In while item = 282
# In while item = 283
# In while item = 284
# In while item = 285
# In while item = 286
# In while item = 287
# In while item = 288
# In while item = 289
# In while item = 290
# In while item = 291
# In while item = 292
# In while item = 293
# In while item = 294
# In while item = 295
# In while item = 3
# In while item = 4
# In while item = 5
# dataset =
#           X  Y   Status  Cluster
# 0     7.95  3     Core        0
# 1     7.30  3     Core        0
# 2     6.65  3     Core        0
# 3     6.00  3     Core        0
# 4     5.55  3     Core        0
# ..     ... ..      ...      ...
# 307  13.85  2  Unknown       -1
# 308  14.05  2  Unknown       -1
# 309  14.25  2  Unknown       -1
# 310  14.50  2  Unknown       -1
# 311  14.60  2  Unknown       -1
#
# [312 rows x 4 columns]
#
# In while item = 6
# In while item = 7
# In while item = 8
# In while item = 9
# In while item = 10
# In while item = 11
# In while item = 12
# In while item = 13
# In while item = 14
# In while item = 15
# In while item = 16
# In while item = 17
# In while item = 18
# In while item = 19
# In while item = 20
# In while item = 21
# In while item = 22
# In while item = 23
# In while item = 24
# In while item = 25
# In while item = 26
# In while item = 27
# In while item = 28
# In while item = 29
# In while item = 30
# In while item = 31
# In while item = 32
# In while item = 33
# In while item = 138
# In while item = 139
# In while item = 140
# In while item = 141
# In while item = 142
# In while item = 143
# In while item = 144
# In while item = 145
# In while item = 146
# In while item = 147
# In while item = 148
# In while item = 149
# In while item = 150
# In while item = 151
# In while item = 152
# In while item = 153
# In while item = 154
# In while item = 155
# In while item = 156
# In while item = 157
# In while item = 158
# In while item = 159
# In while item = 160
# In while item = 161
# In while item = 162
# In while item = 163
# In while item = 164
# In while item = 165
# In while item = 166
# In while item = 167
# In while item = 168
# In while item = 207
# In while item = 208
# In while item = 209
# In while item = 279
# In while item = 280
# In while item = 281
# In while item = 282
# In while item = 283
# In while item = 284
# In while item = 285
# In while item = 286
# In while item = 287
# In while item = 288
# In while item = 289
# In while item = 290
# In while item = 291

# %%
dataset
# Out:
#              X    Y   Status  Cluster  Distance     0    1
# 0         7.95  3.0  Unknown     -1.0  0.000000   NaN  NaN
# 1         7.30  3.0  Unknown     -1.0  0.650000   NaN  NaN
# 2         6.65  3.0  Unknown     -1.0  1.300000   NaN  NaN
# 3         6.00  3.0  Unknown     -1.0  1.950000   NaN  NaN
# 4         5.55  3.0  Unknown     -1.0  2.400000   NaN  NaN
# ...        ...  ...      ...      ...       ...   ...  ...
# 309      14.25  2.0  Unknown     -1.0  6.378871   NaN  NaN
# 310      14.50  2.0  Unknown     -1.0  6.625896   NaN  NaN
# 311      14.60  2.0  Unknown     -1.0  6.724768   NaN  NaN
# Status     NaN  NaN      NaN      NaN       NaN  Core  NaN
# Cluster    NaN  NaN      NaN      NaN       NaN     0  0.0
#
# [314 rows x 7 columns]

# %%
list(set([1, 2, 3]) - set([3, 4]))
# Out:
# [1, 2]
